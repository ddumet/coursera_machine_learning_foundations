# %% [markdown]
# # Song recommender
# The dataset used in this notebook can be found here [song_data.csv](https://d396qusza40orc.cloudfront.net/phoenixassets/song_data.csv)

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.cross_validation import train_test_split

# %%
song_data = pd.read_csv("./data/song_data.csv")

# %%
song_data.head()
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
#
#              title         artist                             song
# 0         The Cove   Jack Johnson          The Cove - Jack Johnson
# 1  Entre Dos Aguas  Paco De Lucia  Entre Dos Aguas - Paco De Lucia
# 2         Stronger     Kanye West            Stronger - Kanye West
# 3   Constellations   Jack Johnson    Constellations - Jack Johnson
# 4     Learn To Fly   Foo Fighters      Learn To Fly - Foo Fighters

# %%
song_data.shape
# Out:
# (1116609, 6)

# %% [markdown]
# ## Explore Data Set

# %% [markdown]
# ### Most frequent songs

# %% [markdown]
# # INSERT HERE GRAPH

# %% [markdown]
# ### Number of unique user

# %%
print("number of unique user:",song_data.loc[:,"user_id"].unique().shape[0])
# Out:
# number of unique user: 66346

# %% [markdown]
# ## Some data needed for our models

# %% [markdown]
# ### List of song, indexed by song_id

# %%
songs = pd.DataFrame(song_data.loc[:,("song_id","song")])

# %%
songs.drop_duplicates("song_id", inplace=True)

# %%
a = songs.reindex(songs.loc[:,"song_id"])

# %%
a
# Out:
#                    song_id song
# song_id
# SOAKIMP12A8C130995     NaN  NaN
# SOBBMDR12A8C13253B     NaN  NaN
# SOBXHDL12A81C204C0     NaN  NaN
# SOBYHAJ12A6701BF1D     NaN  NaN
# SODACBL12A8C13C273     NaN  NaN
# SODDNQT12A6D4F5F7E     NaN  NaN
# SODXRTY12AB0180F3B     NaN  NaN
# SOFGUAY12AB017B0A8     NaN  NaN
# SOFRQTD12A81C233C0     NaN  NaN
# SOHQWYZ12A6D4FA701     NaN  NaN
# SOIYTOA12A6D4F9A23     NaN  NaN
# SOIZAZL12A6701C53B     NaN  NaN
# SOJNNUA12A8AE48C7A     NaN  NaN
# SOJPFQG12A58A7833A     NaN  NaN
# SOKRIMP12A6D4F5DA3     NaN  NaN
# SOLLGNU12AF72A4D4F     NaN  NaN
# SOMGIYR12AB0187973     NaN  NaN
# SOMLMKI12A81C204BC     NaN  NaN
# SOMSQJY12A8C138539     NaN  NaN
# SONSAEZ12A8C138D7A     NaN  NaN
# SOOKGRB12A8C13CD66     NaN  NaN
# SOPCVQE12AC468AF36     NaN  NaN
# SOQIVUD12AB01821D2     NaN  NaN
# SOQJLDY12AAF3B456D     NaN  NaN
# SOQLCKR12A81C22440     NaN  NaN
# SORPMYJ12AF729EB90     NaN  NaN
# SORQHCG12A58A7EEBA     NaN  NaN
# SORUFVF12AB018230B     NaN  NaN
# SORWLTW12A670208FA     NaN  NaN
# SORZASF12A6D4F8CFA     NaN  NaN
# ...                    ...  ...
# SOCTNRU12A6D4FBE21     NaN  NaN
# SOSKVCM12AF729D67B     NaN  NaN
# SONURQC12AB018B245     NaN  NaN
# SOIIMGU12AF72A5401     NaN  NaN
# SOCECEC12A8C134FAF     NaN  NaN
# SOTBSMP12AB017F883     NaN  NaN
# SOLWOTK12A6D4FABAD     NaN  NaN
# SOCQIQY12A8C140363     NaN  NaN
# SOCLFCD12A6D4FA66D     NaN  NaN
# SOSVTWI12A6D4FA672     NaN  NaN
# SOXHCLV12A6D4F6178     NaN  NaN
# SOUSJNT12A67ADE72B     NaN  NaN
# SOHLKEA12A8C13AFE7     NaN  NaN
# SOKXFFZ12AF72A89AD     NaN  NaN
# SOYBRAC12AB01884D9     NaN  NaN
# SODRUKP12AB018E66A     NaN  NaN
# SOTKNMN12A8C1374FE     NaN  NaN
# SOXWEPM12AB0181694     NaN  NaN
# SOEVJPA12B0B809263     NaN  NaN
# SOSJPFC12AB017D6E3     NaN  NaN
# SOIMYQB12A8C135A7E     NaN  NaN
# SOXZSQM12A58A7BAE1     NaN  NaN
# SOSICNK12AB01876BB     NaN  NaN
# SOLJIQB12A8C13ECCB     NaN  NaN
# SOOAAQL12B0B80B6D1     NaN  NaN
# SOTSVAT12A8C138443     NaN  NaN
# SOZXVUF12AC909762A     NaN  NaN
# SOXCFSI12AB0186053     NaN  NaN
# SOLUUFY12A8C138A0B     NaN  NaN
# SOYGMPF12A67ADE5EF     NaN  NaN
#
# [10000 rows x 2 columns]

# %% [markdown]
# ### Split data to train and test sets

# %%
X_train, X_test = train_test_split(song_data,test_size = 0.2,random_state=0)

# %% [markdown]
# ## Popularity based song recommender
# Here popularity will be the most played songs across all users. The model will return the X most popular song.

# %%
def train_popularity_model(data,nb_recommendation):
    
    return(popularity_model)

# %%
song_data.ix[0:10]
# Out:
#                                      user_id             song_id  \
# 0   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995
# 1   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B
# 2   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0
# 3   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D
# 4   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273
# 5   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODDNQT12A6D4F5F7E
# 6   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODXRTY12AB0180F3B
# 7   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFGUAY12AB017B0A8
# 8   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFRQTD12A81C233C0
# 9   b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOHQWYZ12A6D4FA701
# 10  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOIYTOA12A6D4F9A23
#
#     listen_count                           title  \
# 0              1                        The Cove
# 1              2                 Entre Dos Aguas
# 2              1                        Stronger
# 3              1                  Constellations
# 4              1                    Learn To Fly
# 5              5  Apuesta Por El Rock \'N\' Roll
# 6              1                   Paper Gangsta
# 7              1                  Stacked Actors
# 8              1                   Sehr kosmisch
# 9              1  Heaven\'s gonna burn your eyes
# 10             1                  Let It Be Sung
#
#                                                artist  \
# 0                                        Jack Johnson
# 1                                       Paco De Lucia
# 2                                          Kanye West
# 3                                        Jack Johnson
# 4                                        Foo Fighters
# 5                                 Héroes del Silencio
# 6                                           Lady GaGa
# 7                                        Foo Fighters
# 8                                            Harmonia
# 9         Thievery Corporation feat. Emiliana Torrini
# 10  Jack Johnson / Matt Costa / Zach Gill / Dan Le...
#
#                                                  song
# 0                             The Cove - Jack Johnson
# 1                     Entre Dos Aguas - Paco De Lucia
# 2                               Stronger - Kanye West
# 3                       Constellations - Jack Johnson
# 4                         Learn To Fly - Foo Fighters
# 5   Apuesta Por El Rock \'N\' Roll - Héroes del Si...
# 6                           Paper Gangsta - Lady GaGa
# 7                       Stacked Actors - Foo Fighters
# 8                            Sehr kosmisch - Harmonia
# 9   Heaven\'s gonna burn your eyes - Thievery Corp...
# 10  Let It Be Sung - Jack Johnson / Matt Costa / Z...

# %%
pop = song_data.loc[:,["song_id","song"]]
pop = pop.groupby("song_id").count().sort_values("song", ascending = False)
pop.ix[0:10]
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-72-12e26bba5434> in <module>()
#       1 pop = song_data.loc[:,["song_id","song"]]
#       2 pop = pop.groupby("song_id").count().sort_values("song", ascending = False)
# ----> 3 pop.first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
pop.index[0:10]
# Out:
# Index(['SOFRQTD12A81C233C0', 'SOAUWYT12A81C206F1', 'SOBONKR12A58A7A7E0',
#        'SOAXGDH12A8C13F8A1', 'SOSXLTC12AF72A7F54', 'SOEGIYH12A6D4FC0E3',
#        'SONYKOW12AB01849C9', 'SOFLJQZ12A6D4FADA6', 'SOLFXKT12AB017E3E0',
#        'SODJWHY12A8C142CCE'],
#       dtype='object', name='song_id')

# %%
pop1
# Out:
#                                     user_id             song_id  listen_count  \
# 0  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOAKIMP12A8C130995             1
# 1  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBBMDR12A8C13253B             2
# 2  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBXHDL12A81C204C0             1
# 3  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOBYHAJ12A6701BF1D             1
# 4  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODACBL12A8C13C273             1
# 5  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODDNQT12A6D4F5F7E             5
# 6  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SODXRTY12AB0180F3B             1
# 7  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFGUAY12AB017B0A8             1
# 8  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOFRQTD12A81C233C0             1
# 9  b80344d063b5ccb3212f76538f3d9e43d87dca9e  SOHQWYZ12A6D4FA701             1
#
#                             title  \
# 0                        The Cove
# 1                 Entre Dos Aguas
# 2                        Stronger
# 3                  Constellations
# 4                    Learn To Fly
# 5  Apuesta Por El Rock \'N\' Roll
# 6                   Paper Gangsta
# 7                  Stacked Actors
# 8                   Sehr kosmisch
# 9  Heaven\'s gonna burn your eyes
#
#                                         artist  \
# 0                                 Jack Johnson
# 1                                Paco De Lucia
# 2                                   Kanye West
# 3                                 Jack Johnson
# 4                                 Foo Fighters
# 5                          Héroes del Silencio
# 6                                    Lady GaGa
# 7                                 Foo Fighters
# 8                                     Harmonia
# 9  Thievery Corporation feat. Emiliana Torrini
#
#                                                 song
# 0                            The Cove - Jack Johnson
# 1                    Entre Dos Aguas - Paco De Lucia
# 2                              Stronger - Kanye West
# 3                      Constellations - Jack Johnson
# 4                        Learn To Fly - Foo Fighters
# 5  Apuesta Por El Rock \'N\' Roll - Héroes del Si...
# 6                          Paper Gangsta - Lady GaGa
# 7                      Stacked Actors - Foo Fighters
# 8                           Sehr kosmisch - Harmonia
# 9  Heaven\'s gonna burn your eyes - Thievery Corp...
